# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#from scipy.stats import linregress
#from ratelimiter import ratelimiter
#from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
api_key = "3c47a9dd38e22d87f35ab0d87d61bdfd"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
       
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

# create the dataframe for data
cities_df = pd.DataFrame({"City":cities})
cities_df['Cloudiness'] = ''
cities_df['Country'] = ''
cities_df['Date'] = ''
cities_df['Humidity'] = ''
cities_df['Lat'] = ''
cities_df['Lng'] = ''
cities_df['Max Temp'] = ''
cities_df['Wind Speed'] = ''

# %%
count = 1

# Compile data
city_list = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []


for city in cities:
                        # assemble url and make API request
                        print(f"Processing Record {count} of Set 1 | {city}.")
                        count = count + 1
                        
                        target_url = ("http://api.openweathermap.org/data/2.5/weather?"
                                      'appid={0}&q={1}').format(api_key,city)

                            
                        try:
                            #Extract Results
                            response = requests.get(target_url).json()
                            
                            #Add the city info to the lists
                            city_list.append(response['name'])
                            cloudiness.append(response['clouds']['all'])
                            country.append(response['sys']['country'])
                            date.append(response['dt'])
                            humidity.append(response['main']['humidity'])
                            lat.append(response['coord']['lat'])
                            lng.append(response['coord']['lon'])
                            max_temp.append(response['main']['temp_max'])
                            wind_speed.append(response['wind']['speed'])

                        except:
                            print("City not found. Skip...")
# Out:
# Processing Record 1 of Set 1 | kodiak.
# Processing Record 2 of Set 1 | tocopilla.
# Processing Record 3 of Set 1 | iskateley.
# Processing Record 4 of Set 1 | zhitikara.
# City not found. Skip...
# Processing Record 5 of Set 1 | rikitea.
# Processing Record 6 of Set 1 | taolanaro.
# City not found. Skip...
# Processing Record 7 of Set 1 | faanui.
# Processing Record 8 of Set 1 | korla.
# Processing Record 9 of Set 1 | amderma.
# City not found. Skip...
# Processing Record 10 of Set 1 | hilo.
# Processing Record 11 of Set 1 | butaritari.
# Processing Record 12 of Set 1 | port hardy.
# Processing Record 13 of Set 1 | clyde river.
# Processing Record 14 of Set 1 | cape town.
# Processing Record 15 of Set 1 | provideniya.
# Processing Record 16 of Set 1 | avarua.
# Processing Record 17 of Set 1 | bubaque.
# Processing Record 18 of Set 1 | alenquer.
# Processing Record 19 of Set 1 | ancud.
# Processing Record 20 of Set 1 | albany.
# Processing Record 21 of Set 1 | hermanus.
# Processing Record 22 of Set 1 | atuona.
# Processing Record 23 of Set 1 | pevek.
# Processing Record 24 of Set 1 | ushuaia.
# Processing Record 25 of Set 1 | illoqqortoormiut.
# City not found. Skip...
# Processing Record 26 of Set 1 | port alfred.
# Processing Record 27 of Set 1 | torbay.
# Processing Record 28 of Set 1 | tuktoyaktuk.
# Processing Record 29 of Set 1 | bethel.
# Processing Record 30 of Set 1 | kalasin.
# Processing Record 31 of Set 1 | fountain hills.
# Processing Record 32 of Set 1 | busselton.
# Processing Record 33 of Set 1 | mahebourg.
# Processing Record 34 of Set 1 | buarcos.
# Processing Record 35 of Set 1 | saint george.
# Processing Record 36 of Set 1 | samarai.
# Processing Record 37 of Set 1 | dikson.
# Processing Record 38 of Set 1 | vaini.
# Processing Record 39 of Set 1 | puerto ayora.
# Processing Record 40 of Set 1 | paita.
# Processing Record 41 of Set 1 | hobart.
# Processing Record 42 of Set 1 | noumea.
# Processing Record 43 of Set 1 | punta arenas.
# Processing Record 44 of Set 1 | olivehurst.
# Processing Record 45 of Set 1 | puerto madryn.
# Processing Record 46 of Set 1 | garowe.
# Processing Record 47 of Set 1 | chamba.
# Processing Record 48 of Set 1 | rupert.
# Processing Record 49 of Set 1 | upernavik.
# Processing Record 50 of Set 1 | new norfolk.
# Processing Record 51 of Set 1 | egvekinot.
# Processing Record 52 of Set 1 | aloleng.
# Processing Record 53 of Set 1 | assens.
# Processing Record 54 of Set 1 | barrow.
# Processing Record 55 of Set 1 | hovd.
# Processing Record 56 of Set 1 | dosso.
# Processing Record 57 of Set 1 | nelson bay.
# Processing Record 58 of Set 1 | nikolskoye.
# Processing Record 59 of Set 1 | mimongo.
# Processing Record 60 of Set 1 | guarapari.
# Processing Record 61 of Set 1 | camacha.
# Processing Record 62 of Set 1 | george town.
# Processing Record 63 of Set 1 | kurumkan.
# Processing Record 64 of Set 1 | rottenmann.
# Processing Record 65 of Set 1 | cabo san lucas.
# Processing Record 66 of Set 1 | arraial do cabo.
# Processing Record 67 of Set 1 | severo-kurilsk.
# Processing Record 68 of Set 1 | maine-soroa.
# Processing Record 69 of Set 1 | aykhal.
# Processing Record 70 of Set 1 | nanortalik.
# Processing Record 71 of Set 1 | kavieng.
# Processing Record 72 of Set 1 | borogontsy.
# Processing Record 73 of Set 1 | vaitape.
# Processing Record 74 of Set 1 | zhemchuzhnyy.
# City not found. Skip...
# Processing Record 75 of Set 1 | villa carlos paz.
# Processing Record 76 of Set 1 | kapaa.
# Processing Record 77 of Set 1 | tsihombe.
# City not found. Skip...
# Processing Record 78 of Set 1 | khatanga.
# Processing Record 79 of Set 1 | aberystwyth.
# Processing Record 80 of Set 1 | chokurdakh.
# Processing Record 81 of Set 1 | sulingen.
# Processing Record 82 of Set 1 | mataura.
# Processing Record 83 of Set 1 | boke.
# Processing Record 84 of Set 1 | saint-philippe.
# Processing Record 85 of Set 1 | puerto quijarro.
# Processing Record 86 of Set 1 | sitka.
# Processing Record 87 of Set 1 | atar.
# Processing Record 88 of Set 1 | castro.
# Processing Record 89 of Set 1 | jumla.
# Processing Record 90 of Set 1 | baruun-urt.
# Processing Record 91 of Set 1 | port elizabeth.
# Processing Record 92 of Set 1 | barentsburg.
# City not found. Skip...
# Processing Record 93 of Set 1 | rocha.
# Processing Record 94 of Set 1 | saleaula.
# City not found. Skip...
# Processing Record 95 of Set 1 | kirensk.
# Processing Record 96 of Set 1 | yellowknife.
# Processing Record 97 of Set 1 | thompson.
# Processing Record 98 of Set 1 | bluff.
# Processing Record 99 of Set 1 | chuy.
# Processing Record 100 of Set 1 | mareeba.
# Processing Record 101 of Set 1 | carnarvon.
# Processing Record 102 of Set 1 | dhidhdhoo.
# Processing Record 103 of Set 1 | barbar.
# City not found. Skip...
# Processing Record 104 of Set 1 | luderitz.
# Processing Record 105 of Set 1 | alyangula.
# Processing Record 106 of Set 1 | saint anthony.
# Processing Record 107 of Set 1 | henties bay.
# Processing Record 108 of Set 1 | ondangwa.
# Processing Record 109 of Set 1 | mys shmidta.
# City not found. Skip...
# Processing Record 110 of Set 1 | maragogi.
# Processing Record 111 of Set 1 | port moresby.
# Processing Record 112 of Set 1 | fortuna.
# Processing Record 113 of Set 1 | altamira.
# Processing Record 114 of Set 1 | fuyu.
# Processing Record 115 of Set 1 | mancio lima.
# Processing Record 116 of Set 1 | kochki.
# Processing Record 117 of Set 1 | lebu.
# Processing Record 118 of Set 1 | labuhan.
# Processing Record 119 of Set 1 | kavaratti.
# Processing Record 120 of Set 1 | ilulissat.
# Processing Record 121 of Set 1 | tiksi.
# Processing Record 122 of Set 1 | grand gaube.
# Processing Record 123 of Set 1 | svetlaya.
# Processing Record 124 of Set 1 | saskylakh.
# Processing Record 125 of Set 1 | san patricio.
# Processing Record 126 of Set 1 | sabha.
# Processing Record 127 of Set 1 | goundam.
# Processing Record 128 of Set 1 | hithadhoo.
# Processing Record 129 of Set 1 | barabai.
# Processing Record 130 of Set 1 | kungurtug.
# Processing Record 131 of Set 1 | ribeira grande.
# Processing Record 132 of Set 1 | puerto escondido.
# Processing Record 133 of Set 1 | laiyang.
# Processing Record 134 of Set 1 | general pico.
# Processing Record 135 of Set 1 | isangel.
# Processing Record 136 of Set 1 | sao joao da barra.
# Processing Record 137 of Set 1 | georgetown.
# Processing Record 138 of Set 1 | husavik.
# Processing Record 139 of Set 1 | karera.
# Processing Record 140 of Set 1 | grindavik.
# Processing Record 141 of Set 1 | vila.
# Processing Record 142 of Set 1 | makakilo city.
# Processing Record 143 of Set 1 | bambous virieux.
# Processing Record 144 of Set 1 | bredasdorp.
# Processing Record 145 of Set 1 | novouzensk.
# Processing Record 146 of Set 1 | santa maria visitacion.
# Processing Record 147 of Set 1 | malanje.
# Processing Record 148 of Set 1 | jamestown.
# Processing Record 149 of Set 1 | miri.
# Processing Record 150 of Set 1 | beringovskiy.
# Processing Record 151 of Set 1 | port blair.
# Processing Record 152 of Set 1 | salalah.
# Processing Record 153 of Set 1 | shirokiy.
# Processing Record 154 of Set 1 | beli manastir.
# Processing Record 155 of Set 1 | mehamn.
# Processing Record 156 of Set 1 | heihe.
# Processing Record 157 of Set 1 | xuanhua.
# Processing Record 158 of Set 1 | kaniama.
# Processing Record 159 of Set 1 | quelimane.
# Processing Record 160 of Set 1 | reconquista.
# Processing Record 161 of Set 1 | show low.
# Processing Record 162 of Set 1 | cherskiy.
# Processing Record 163 of Set 1 | touros.
# Processing Record 164 of Set 1 | cortez.
# Processing Record 165 of Set 1 | tura.
# Processing Record 166 of Set 1 | nizhneyansk.
# City not found. Skip...
# Processing Record 167 of Set 1 | mar del plata.
# Processing Record 168 of Set 1 | longyearbyen.
# Processing Record 169 of Set 1 | skelleftea.
# Processing Record 170 of Set 1 | tuatapere.
# Processing Record 171 of Set 1 | jablah.
# Processing Record 172 of Set 1 | grand river south east.
# City not found. Skip...
# Processing Record 173 of Set 1 | jacareacanga.
# Processing Record 174 of Set 1 | chulman.
# Processing Record 175 of Set 1 | pervoye maya.
# Processing Record 176 of Set 1 | lompoc.
# Processing Record 177 of Set 1 | methoni.
# Processing Record 178 of Set 1 | zhangjiakou.
# Processing Record 179 of Set 1 | orlik.
# Processing Record 180 of Set 1 | troitsko-pechorsk.
# Processing Record 181 of Set 1 | bengkulu.
# Processing Record 182 of Set 1 | pisco.
# Processing Record 183 of Set 1 | meulaboh.
# Processing Record 184 of Set 1 | berlevag.
# Processing Record 185 of Set 1 | okhotsk.
# Processing Record 186 of Set 1 | basco.
# Processing Record 187 of Set 1 | namibe.
# Processing Record 188 of Set 1 | marsa matruh.
# Processing Record 189 of Set 1 | hays.
# Processing Record 190 of Set 1 | coihaique.
# Processing Record 191 of Set 1 | vredendal.
# Processing Record 192 of Set 1 | pandan.
# Processing Record 193 of Set 1 | kieta.
# Processing Record 194 of Set 1 | quang ngai.
# Processing Record 195 of Set 1 | palmer.
# Processing Record 196 of Set 1 | phan rang.
# City not found. Skip...
# Processing Record 197 of Set 1 | garissa.
# Processing Record 198 of Set 1 | tilichiki.
# Processing Record 199 of Set 1 | mogadishu.
# Processing Record 200 of Set 1 | russell.
# Processing Record 201 of Set 1 | meyungs.
# City not found. Skip...
# Processing Record 202 of Set 1 | tahoua.
# Processing Record 203 of Set 1 | sungairaya.
# Processing Record 204 of Set 1 | hami.
# Processing Record 205 of Set 1 | dingle.
# Processing Record 206 of Set 1 | maku.
# Processing Record 207 of Set 1 | geraldton.
# Processing Record 208 of Set 1 | keti bandar.
# Processing Record 209 of Set 1 | fairbanks.
# Processing Record 210 of Set 1 | road town.
# Processing Record 211 of Set 1 | mpanda.
# Processing Record 212 of Set 1 | katsuura.
# Processing Record 213 of Set 1 | jabiru.
# City not found. Skip...
# Processing Record 214 of Set 1 | qaanaaq.
# Processing Record 215 of Set 1 | san cristobal.
# Processing Record 216 of Set 1 | pathalgaon.
# Processing Record 217 of Set 1 | dicabisagan.
# Processing Record 218 of Set 1 | tasiilaq.
# Processing Record 219 of Set 1 | ribeirao bonito.
# Processing Record 220 of Set 1 | khandyga.
# Processing Record 221 of Set 1 | camana.
# Processing Record 222 of Set 1 | east london.
# Processing Record 223 of Set 1 | palabuhanratu.
# City not found. Skip...
# Processing Record 224 of Set 1 | conde.
# Processing Record 225 of Set 1 | bourail.
# Processing Record 226 of Set 1 | port keats.
# Processing Record 227 of Set 1 | arlit.
# Processing Record 228 of Set 1 | saint-georges.
# Processing Record 229 of Set 1 | juneau.
# Processing Record 230 of Set 1 | airai.
# Processing Record 231 of Set 1 | iralaya.
# Processing Record 232 of Set 1 | oyon.
# Processing Record 233 of Set 1 | ranong.
# Processing Record 234 of Set 1 | umea.
# Processing Record 235 of Set 1 | jupiter.
# Processing Record 236 of Set 1 | champerico.
# Processing Record 237 of Set 1 | isiro.
# Processing Record 238 of Set 1 | urusha.
# Processing Record 239 of Set 1 | belushya guba.
# City not found. Skip...
# Processing Record 240 of Set 1 | roma.
# Processing Record 241 of Set 1 | cidreira.
# Processing Record 242 of Set 1 | umm lajj.
# Processing Record 243 of Set 1 | caravelas.
# Processing Record 244 of Set 1 | mount gambier.
# Processing Record 245 of Set 1 | chernyshevskiy.
# Processing Record 246 of Set 1 | dudinka.
# Processing Record 247 of Set 1 | japura.
# Processing Record 248 of Set 1 | aktau.
# Processing Record 249 of Set 1 | broome.
# Processing Record 250 of Set 1 | puerto leguizamo.
# Processing Record 251 of Set 1 | kudahuvadhoo.
# Processing Record 252 of Set 1 | vanimo.
# Processing Record 253 of Set 1 | tenenkou.
# Processing Record 254 of Set 1 | jibuti.
# Processing Record 255 of Set 1 | taunggyi.
# Processing Record 256 of Set 1 | longview.
# Processing Record 257 of Set 1 | caconda.
# Processing Record 258 of Set 1 | nayudupeta.
# Processing Record 259 of Set 1 | hambantota.
# Processing Record 260 of Set 1 | carroll.
# Processing Record 261 of Set 1 | aktash.
# Processing Record 262 of Set 1 | along.
# Processing Record 263 of Set 1 | gulshat.
# City not found. Skip...
# Processing Record 264 of Set 1 | kaitangata.
# Processing Record 265 of Set 1 | marzuq.
# Processing Record 266 of Set 1 | cullman.
# Processing Record 267 of Set 1 | nkoteng.
# Processing Record 268 of Set 1 | khonuu.
# City not found. Skip...
# Processing Record 269 of Set 1 | we.
# City not found. Skip...
# Processing Record 270 of Set 1 | greenville.
# Processing Record 271 of Set 1 | gat.
# Processing Record 272 of Set 1 | haines junction.
# Processing Record 273 of Set 1 | palana.
# Processing Record 274 of Set 1 | sofiysk.
# City not found. Skip...
# Processing Record 275 of Set 1 | princeton.
# Processing Record 276 of Set 1 | pangoa.
# Processing Record 277 of Set 1 | afmadu.
# City not found. Skip...
# Processing Record 278 of Set 1 | nemuro.
# Processing Record 279 of Set 1 | gillette.
# Processing Record 280 of Set 1 | pyapon.
# Processing Record 281 of Set 1 | jardim.
# Processing Record 282 of Set 1 | codrington.
# Processing Record 283 of Set 1 | svetlogorsk.
# Processing Record 284 of Set 1 | yanchukan.
# City not found. Skip...
# Processing Record 285 of Set 1 | norman wells.
# Processing Record 286 of Set 1 | snyder.
# Processing Record 287 of Set 1 | potam.
# Processing Record 288 of Set 1 | talnakh.
# Processing Record 289 of Set 1 | bonnyville.
# Processing Record 290 of Set 1 | marfino.
# Processing Record 291 of Set 1 | taylor.
# Processing Record 292 of Set 1 | hasaki.
# Processing Record 293 of Set 1 | bilibino.
# Processing Record 294 of Set 1 | jalu.
# Processing Record 295 of Set 1 | tigil.
# Processing Record 296 of Set 1 | raga.
# Processing Record 297 of Set 1 | ostrovnoy.
# Processing Record 298 of Set 1 | ternate.
# Processing Record 299 of Set 1 | los llanos de aridane.
# Processing Record 300 of Set 1 | marshall.
# Processing Record 301 of Set 1 | tartagal.
# Processing Record 302 of Set 1 | sentyabrskiy.
# City not found. Skip...
# Processing Record 303 of Set 1 | barquisimeto.
# Processing Record 304 of Set 1 | portneuf.
# Processing Record 305 of Set 1 | katherine.
# Processing Record 306 of Set 1 | akureyri.
# Processing Record 307 of Set 1 | shar.
# Processing Record 308 of Set 1 | pangnirtung.
# Processing Record 309 of Set 1 | sao filipe.
# Processing Record 310 of Set 1 | attawapiskat.
# City not found. Skip...
# Processing Record 311 of Set 1 | dzilam gonzalez.
# Processing Record 312 of Set 1 | buluang.
# Processing Record 313 of Set 1 | acarau.
# Processing Record 314 of Set 1 | barawe.
# City not found. Skip...
# Processing Record 315 of Set 1 | westport.
# Processing Record 316 of Set 1 | bilma.
# Processing Record 317 of Set 1 | aginskoye.
# Processing Record 318 of Set 1 | cesvaine.
# Processing Record 319 of Set 1 | suez.
# Processing Record 320 of Set 1 | kruisfontein.
# Processing Record 321 of Set 1 | santo tomas.
# Processing Record 322 of Set 1 | umzimvubu.
# City not found. Skip...
# Processing Record 323 of Set 1 | fria.
# Processing Record 324 of Set 1 | vardo.
# Processing Record 325 of Set 1 | ulcinj.
# Processing Record 326 of Set 1 | sistranda.
# Processing Record 327 of Set 1 | ramasukha.
# City not found. Skip...
# Processing Record 328 of Set 1 | cabinda.
# Processing Record 329 of Set 1 | savinka.
# Processing Record 330 of Set 1 | olafsvik.
# Processing Record 331 of Set 1 | freeport.
# Processing Record 332 of Set 1 | karratha.
# Processing Record 333 of Set 1 | cayenne.
# Processing Record 334 of Set 1 | mwaya.
# Processing Record 335 of Set 1 | chute-aux-outardes.
# Processing Record 336 of Set 1 | susanville.
# Processing Record 337 of Set 1 | ganzhou.
# Processing Record 338 of Set 1 | itaituba.
# Processing Record 339 of Set 1 | czarnkow.
# Processing Record 340 of Set 1 | pak phanang.
# Processing Record 341 of Set 1 | pampierstad.
# Processing Record 342 of Set 1 | alice springs.
# Processing Record 343 of Set 1 | grand-santi.
# Processing Record 344 of Set 1 | kabinda.
# Processing Record 345 of Set 1 | aripuana.
# Processing Record 346 of Set 1 | maltahohe.
# Processing Record 347 of Set 1 | abomsa.
# Processing Record 348 of Set 1 | eyl.
# Processing Record 349 of Set 1 | ossora.
# Processing Record 350 of Set 1 | victoria.
# Processing Record 351 of Set 1 | praia da vitoria.
# Processing Record 352 of Set 1 | esperance.
# Processing Record 353 of Set 1 | sept-iles.
# Processing Record 354 of Set 1 | birnin kebbi.
# Processing Record 355 of Set 1 | beian.
# Processing Record 356 of Set 1 | bamako.
# Processing Record 357 of Set 1 | narsaq.
# Processing Record 358 of Set 1 | lagoa.
# Processing Record 359 of Set 1 | kenai.
# Processing Record 360 of Set 1 | nouadhibou.
# Processing Record 361 of Set 1 | nantucket.
# Processing Record 362 of Set 1 | zhigansk.
# Processing Record 363 of Set 1 | dubti.
# Processing Record 364 of Set 1 | saldanha.
# Processing Record 365 of Set 1 | lujan.
# Processing Record 366 of Set 1 | oriximina.
# Processing Record 367 of Set 1 | lulea.
# Processing Record 368 of Set 1 | nome.
# Processing Record 369 of Set 1 | gurgan.
# City not found. Skip...
# Processing Record 370 of Set 1 | rudbar.
# Processing Record 371 of Set 1 | baiyin.
# Processing Record 372 of Set 1 | gamba.
# Processing Record 373 of Set 1 | pecos.
# Processing Record 374 of Set 1 | kostroma.
# Processing Record 375 of Set 1 | kiruna.
# Processing Record 376 of Set 1 | horta.
# Processing Record 377 of Set 1 | lakes entrance.
# Processing Record 378 of Set 1 | safaqis.
# City not found. Skip...
# Processing Record 379 of Set 1 | pontes e lacerda.
# Processing Record 380 of Set 1 | siilinjarvi.
# Processing Record 381 of Set 1 | ilo.
# Processing Record 382 of Set 1 | kilindoni.
# Processing Record 383 of Set 1 | eskasem.
# City not found. Skip...
# Processing Record 384 of Set 1 | lorengau.
# Processing Record 385 of Set 1 | coahuayana.
# Processing Record 386 of Set 1 | san policarpo.
# Processing Record 387 of Set 1 | santa rosa.
# Processing Record 388 of Set 1 | alexandria.
# Processing Record 389 of Set 1 | gidole.
# Processing Record 390 of Set 1 | sinop.
# Processing Record 391 of Set 1 | cabedelo.
# Processing Record 392 of Set 1 | arys.
# Processing Record 393 of Set 1 | ponta do sol.
# Processing Record 394 of Set 1 | ormara.
# Processing Record 395 of Set 1 | yining.
# Processing Record 396 of Set 1 | piedade.
# Processing Record 397 of Set 1 | tunduru.
# City not found. Skip...
# Processing Record 398 of Set 1 | dalvik.
# Processing Record 399 of Set 1 | hirara.
# Processing Record 400 of Set 1 | flinders.
# Processing Record 401 of Set 1 | tiznit.
# Processing Record 402 of Set 1 | klaksvik.
# Processing Record 403 of Set 1 | srednekolymsk.
# Processing Record 404 of Set 1 | ketchikan.
# Processing Record 405 of Set 1 | savannah bight.
# Processing Record 406 of Set 1 | kushima.
# Processing Record 407 of Set 1 | iqaluit.
# Processing Record 408 of Set 1 | karasjok.
# Processing Record 409 of Set 1 | navahrudak.
# Processing Record 410 of Set 1 | rosaryville.
# Processing Record 411 of Set 1 | kampot.
# Processing Record 412 of Set 1 | salinopolis.
# Processing Record 413 of Set 1 | kajaani.
# Processing Record 414 of Set 1 | sao jose da coroa grande.
# Processing Record 415 of Set 1 | faya.
# Processing Record 416 of Set 1 | trairi.
# Processing Record 417 of Set 1 | ksenyevka.
# City not found. Skip...
# Processing Record 418 of Set 1 | adrar.
# Processing Record 419 of Set 1 | vila velha.
# Processing Record 420 of Set 1 | verkhnevilyuysk.
# Processing Record 421 of Set 1 | rawson.
# Processing Record 422 of Set 1 | hokitika.
# Processing Record 423 of Set 1 | bonavista.
# Processing Record 424 of Set 1 | plettenberg bay.
# Processing Record 425 of Set 1 | umm durman.
# City not found. Skip...
# Processing Record 426 of Set 1 | komsomolskiy.
# Processing Record 427 of Set 1 | jutai.
# Processing Record 428 of Set 1 | tezu.
# Processing Record 429 of Set 1 | kon tum.
# Processing Record 430 of Set 1 | lang son.
# Processing Record 431 of Set 1 | kayes.
# Processing Record 432 of Set 1 | koryazhma.
# Processing Record 433 of Set 1 | bechem.
# Processing Record 434 of Set 1 | bell ville.
# Processing Record 435 of Set 1 | namatanai.
# Processing Record 436 of Set 1 | jalalpur.
# Processing Record 437 of Set 1 | maneadero.
# Processing Record 438 of Set 1 | kijang.
# Processing Record 439 of Set 1 | chase.
# Processing Record 440 of Set 1 | sambava.
# Processing Record 441 of Set 1 | angoche.
# Processing Record 442 of Set 1 | carutapera.
# Processing Record 443 of Set 1 | boa vista.
# Processing Record 444 of Set 1 | ruiru.
# Processing Record 445 of Set 1 | kendari.
# Processing Record 446 of Set 1 | rapid valley.
# Processing Record 447 of Set 1 | tiruvottiyur.
# City not found. Skip...
# Processing Record 448 of Set 1 | axim.
# Processing Record 449 of Set 1 | khipro.
# Processing Record 450 of Set 1 | margate.
# Processing Record 451 of Set 1 | rjukan.
# Processing Record 452 of Set 1 | mitikas.
# Processing Record 453 of Set 1 | emmett.
# Processing Record 454 of Set 1 | tazovskiy.
# Processing Record 455 of Set 1 | askarovo.
# Processing Record 456 of Set 1 | linares.
# Processing Record 457 of Set 1 | laguna.
# Processing Record 458 of Set 1 | beloha.
# Processing Record 459 of Set 1 | yantal.
# Processing Record 460 of Set 1 | kargasok.
# Processing Record 461 of Set 1 | kharp.
# Processing Record 462 of Set 1 | newport.
# Processing Record 463 of Set 1 | estelle.
# Processing Record 464 of Set 1 | gizo.
# Processing Record 465 of Set 1 | winslow.
# Processing Record 466 of Set 1 | wanaka.
# Processing Record 467 of Set 1 | college.
# Processing Record 468 of Set 1 | ajdabiya.
# Processing Record 469 of Set 1 | avera.
# Processing Record 470 of Set 1 | vitim.
# Processing Record 471 of Set 1 | amalapuram.
# Processing Record 472 of Set 1 | sisimiut.
# Processing Record 473 of Set 1 | libreville.
# Processing Record 474 of Set 1 | acari.
# Processing Record 475 of Set 1 | waipawa.
# Processing Record 476 of Set 1 | khorixas.
# Processing Record 477 of Set 1 | yuanping.
# Processing Record 478 of Set 1 | alta.
# Processing Record 479 of Set 1 | tiarei.
# Processing Record 480 of Set 1 | portland.
# Processing Record 481 of Set 1 | poplar bluff.
# Processing Record 482 of Set 1 | prescott.
# Processing Record 483 of Set 1 | martapura.
# Processing Record 484 of Set 1 | san carlos de bariloche.
# Processing Record 485 of Set 1 | oktyabrskoye.
# Processing Record 486 of Set 1 | antofagasta.
# Processing Record 487 of Set 1 | shingu.
# Processing Record 488 of Set 1 | marcona.
# City not found. Skip...
# Processing Record 489 of Set 1 | alofi.
# Processing Record 490 of Set 1 | la gaulette.
# City not found. Skip...
# Processing Record 491 of Set 1 | orange cove.
# Processing Record 492 of Set 1 | abiy adi.
# City not found. Skip...
# Processing Record 493 of Set 1 | la grande.
# Processing Record 494 of Set 1 | duz.
# City not found. Skip...
# Processing Record 495 of Set 1 | paulo afonso.
# Processing Record 496 of Set 1 | bereznik.
# Processing Record 497 of Set 1 | melita.
# Processing Record 498 of Set 1 | omboue.
# Processing Record 499 of Set 1 | aksu.
# Processing Record 500 of Set 1 | xianyang.
# Processing Record 501 of Set 1 | dauriya.
# Processing Record 502 of Set 1 | teknaf.
# Processing Record 503 of Set 1 | verkhnyaya inta.
# Processing Record 504 of Set 1 | rosarno.
# Processing Record 505 of Set 1 | nyahururu.
# Processing Record 506 of Set 1 | sena madureira.
# Processing Record 507 of Set 1 | marovoay.
# Processing Record 508 of Set 1 | liverpool.
# Processing Record 509 of Set 1 | sturgis.
# Processing Record 510 of Set 1 | bolungarvik.
# City not found. Skip...
# Processing Record 511 of Set 1 | halifax.
# Processing Record 512 of Set 1 | aklavik.
# Processing Record 513 of Set 1 | coquimbo.
# Processing Record 514 of Set 1 | gobabis.
# Processing Record 515 of Set 1 | kutum.
# Processing Record 516 of Set 1 | vao.
# Processing Record 517 of Set 1 | bouza.
# Processing Record 518 of Set 1 | batagay-alyta.
# Processing Record 519 of Set 1 | poum.
# Processing Record 520 of Set 1 | karakendzha.
# City not found. Skip...
# Processing Record 521 of Set 1 | zambezi.
# Processing Record 522 of Set 1 | tooele.
# Processing Record 523 of Set 1 | manavalakurichi.
# Processing Record 524 of Set 1 | tillabery.
# City not found. Skip...
# Processing Record 525 of Set 1 | homestead.
# Processing Record 526 of Set 1 | andevoranto.
# City not found. Skip...
# Processing Record 527 of Set 1 | kahului.
# Processing Record 528 of Set 1 | magadan.
# Processing Record 529 of Set 1 | half moon bay.
# Processing Record 530 of Set 1 | anuradhapura.
# Processing Record 531 of Set 1 | mackenzie.
# Processing Record 532 of Set 1 | lae.
# Processing Record 533 of Set 1 | pompeia.
# Processing Record 534 of Set 1 | male.
# Processing Record 535 of Set 1 | kichera.
# Processing Record 536 of Set 1 | batamshinskiy.
# Processing Record 537 of Set 1 | mezhdurechensk.
# Processing Record 538 of Set 1 | padang.
# Processing Record 539 of Set 1 | bosaso.
# Processing Record 540 of Set 1 | san antonio.
# Processing Record 541 of Set 1 | hobyo.
# Processing Record 542 of Set 1 | cozumel.
# Processing Record 543 of Set 1 | karangampel.
# Processing Record 544 of Set 1 | fevralsk.
# City not found. Skip...
# Processing Record 545 of Set 1 | hualmay.
# Processing Record 546 of Set 1 | veraval.
# Processing Record 547 of Set 1 | azimur.
# City not found. Skip...
# Processing Record 548 of Set 1 | palmas.
# Processing Record 549 of Set 1 | bull savanna.
# Processing Record 550 of Set 1 | sauda.
# Processing Record 551 of Set 1 | labutta.
# City not found. Skip...
# Processing Record 552 of Set 1 | inderborskiy.
# City not found. Skip...
# Processing Record 553 of Set 1 | beni mazar.
# Processing Record 554 of Set 1 | san jose.
# Processing Record 555 of Set 1 | solano.
# Processing Record 556 of Set 1 | tra vinh.
# Processing Record 557 of Set 1 | duldurga.
# Processing Record 558 of Set 1 | ushtobe.
# Processing Record 559 of Set 1 | koshurnikovo.
# Processing Record 560 of Set 1 | puerto ayacucho.
# Processing Record 561 of Set 1 | svay rieng.
# Processing Record 562 of Set 1 | maputo.
# Processing Record 563 of Set 1 | chongwe.
# Processing Record 564 of Set 1 | bartica.
# Processing Record 565 of Set 1 | sobolevo.
# Processing Record 566 of Set 1 | chapleau.
# Processing Record 567 of Set 1 | leningradskiy.
# Processing Record 568 of Set 1 | uyovu.
# Processing Record 569 of Set 1 | australind.
# Processing Record 570 of Set 1 | buerarema.
# Processing Record 571 of Set 1 | sosnovo-ozerskoye.
# Processing Record 572 of Set 1 | seoul.
# Processing Record 573 of Set 1 | zhezkazgan.
# Processing Record 574 of Set 1 | aketi.
# Processing Record 575 of Set 1 | vila franca do campo.
# Processing Record 576 of Set 1 | lerwick.
# Processing Record 577 of Set 1 | great falls.
# Processing Record 578 of Set 1 | huilong.
# Processing Record 579 of Set 1 | hofn.
# Processing Record 580 of Set 1 | marihatag.
# Processing Record 581 of Set 1 | elko.
# Processing Record 582 of Set 1 | saint-joseph.
# Processing Record 583 of Set 1 | guerrero negro.
# Processing Record 584 of Set 1 | venice.
# Processing Record 585 of Set 1 | nikolayevsk-na-amure.
# Processing Record 586 of Set 1 | broken hill.
# Processing Record 587 of Set 1 | kaseda.
# Processing Record 588 of Set 1 | yushala.
# Processing Record 589 of Set 1 | lavrentiya.
# Processing Record 590 of Set 1 | sarahan.
# Processing Record 591 of Set 1 | mackay.
# Processing Record 592 of Set 1 | puri.
# Processing Record 593 of Set 1 | sao felix do xingu.
# Processing Record 594 of Set 1 | koulamoutou.
# Processing Record 595 of Set 1 | el paso.
# Processing Record 596 of Set 1 | chisindia.
# Processing Record 597 of Set 1 | gangotri.
# City not found. Skip...
# Processing Record 598 of Set 1 | kaspiysk.
# Processing Record 599 of Set 1 | constitucion.
# Processing Record 600 of Set 1 | halalo.
# City not found. Skip...
# Processing Record 601 of Set 1 | ovalle.
# Processing Record 602 of Set 1 | trujillo.
# Processing Record 603 of Set 1 | korem.
# Processing Record 604 of Set 1 | cape coast.
# Processing Record 605 of Set 1 | gujan-mestras.
# Processing Record 606 of Set 1 | kailua.
# Processing Record 607 of Set 1 | killybegs.
# Processing Record 608 of Set 1 | marsh harbour.
# Processing Record 609 of Set 1 | armidale.
# Processing Record 610 of Set 1 | tlahualilo.
# City not found. Skip...
# Processing Record 611 of Set 1 | kure.
# Processing Record 612 of Set 1 | waddan.
# Processing Record 613 of Set 1 | abay.
# Processing Record 614 of Set 1 | salamiyah.
# Processing Record 615 of Set 1 | taltal.
# Processing Record 616 of Set 1 | tumannyy.
# City not found. Skip...
# Processing Record 617 of Set 1 | maturin.
# Processing Record 618 of Set 1 | caceres.

# %%
# max temp to F from Kelvin
max_temp = [(9/5)*(x - 273) + 32 for x in max_temp]

# dataframe with the city info
city_df = pd.DataFrame({
                            "City":city_list,
                            "Cloudiness":cloudiness,
                            "Country":country,
                            "Date":date,
                            "Humidity":humidity,
                            "Lat":lat,
                            "Lng":lng,
                            "Max Temp":max_temp,
                            "Wind Speed":wind_speed})

# write csv dataframe
city_df.to_csv("cities.csv")
city_df.head()
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Saint Paul Harbor          90      US  1592697007        87  57.79 -152.41
# 1          Tocopilla          20      CL  1592697253        69 -22.09  -70.20
# 2          Iskateley         100      RU  1592697253        88  67.68   53.15
# 3            Rikitea          57      PF  1592696721        84 -23.12 -134.97
# 4             Faanui          63      PF  1592697046        80 -16.48 -151.75
#
#    Max Temp  Wind Speed
# 0    52.070        5.70
# 1    60.908        3.40
# 2    40.892        9.03
# 3    76.262        5.28
# 4    80.114        4.98

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
ax.set_title('City Latitude vs. Max Temperature')
ax.scatter(city_df['Lat'],city_df['Max Temp'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_max_temp.png')

# %%
#Measured As the City is Closer to the Equater the Max Temperature is Higher

# %%
# Plot Latitude vs Hunidity

fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
ax.set_title('City Latitude vs. Humidity')
ax.scatter(city_df['Lat'],city_df['Humidity'],edgecolors='black')
plt.grid()

# Save File
fig.savefig('lat_vs_humidity.png')

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Shows theC City's latitude Being Closer to the Equator Does Not Correspond to the Humidity Level of the City

# %%
# Plot Latitude vs Cloudiness

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
ax.set_title('City Latitude vs. Cloudiness')
ax.scatter(city_df['Lat'],city_df['Cloudiness'],edgecolors='black')
plt.grid()

# Save File
fig.savefig('lat_vs_cloudiness.png')

# %%
#Unable to Get this Analysist to Work

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Plot Latitude vs Wind Speed
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
ax.set_title('City Latitude vs. Wind Speed')
ax.scatter(city_df['Lat'],city_df['Wind Speed'],edgecolors='black')
plt.grid()

# Save File
fig.savefig('lat_vs_wind_speed.png')

# %%
# No Relationship Between Wind Speed and Location narest to Equator

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern = cities.query(f"Lat >= {L}")
Southern = cities.query(f"Lat <= {L}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6c9140b76681> in <module>
#       1 # Create Northern and Southern Hemisphere DataFrames
# ----> 2 Northern = city.query(f"Lat >= {L}")
#       3 Southern = city.query(f"Lat <= {L}")
#
# AttributeError: 'str' object has no attribute 'query'

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=Northern['Lat']
y_values=Northern['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,270),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.title('Latitude vs Max Temp (Northern Hemisphere)')
plt.style.use("classic")
R2="R^2="+str(round(rvalue,4))
plt.annotate(R2,(0,260),fontsize=15,color="red")
print(f"The correlation coefficient(R^2) is: {rvalue}")
plt.savefig("Latitude vs Max Temp (Northern Hemisphere).png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
